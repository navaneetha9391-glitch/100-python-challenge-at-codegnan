# %%
s= input() # srinu@123
validate_string = "fsdjhiourhgunJBUYEUDHN123456@_"
if len(s) >=8:
    # check atleast one upper case and one lower case letter
      # - first character is upper or lower
    if s[0].isupper() or s[0].islower():
        for i in range(1, len(s)):
           if s[i] not in validate_string:
               print(f"Invalid username because character {s[i]}")
               break
        else:
           print("valid_string")
      
      # - special characters ('_','@')
      #- it contains digits
    else:    
      print("username not valid because first character is not upper or not lower")
else:
      print("username not valid because first character is not upper or not lower")
# Out:
#  string
# username not valid because first character is not upper or not lower

# %%
for i in range(1,6):
    if i == 3:
        continue
    print(i)
else:
    print("program done")
# Out:
# 1
# 2
# 4
# 5
# program done

# %%
for i in range(1,6):
    if i == 3:
        break
    print(i)
else:
    print("program done")
# Out:
# 1
# 2

# %%
def addition_of_two_numbers(a,b) :
    s=a+b 
    return s
result = addition_of_two_numbers(10,20)
print(result)
# Out:
# 30

# %%
def addition(a,b):
    return a+b
def subtraction(a,b):   
    return a-b
def multiple(a,b):   
    return a*b
def division(a,b):
    if b==0:
        return "Zero division not possible"
    return a/b
if __name__ == "__main__":
    print("Welcome to small level calculator")
    n1 = int(input("Enter number 1:"))
    n2 = int(input("Enter number 2:"))
    print("1. addition /n 2. subtraction /n 3. multiple /n 4. division")
    choice = int(input("Enter your choice:"))
    if choice == 1:
        print("addition of two numbers s:", addition(n1,n2))
    elif choice == 2:
        print("subtraction of two numbers s:", subtraction(n1,n2))
    elif choice == 3:
        print("multiple of two numbers s:", multiple(n1,n2))
    elif choice == 4:
        print("division of two numbers s:", division(n1,n2))
    else :
        print("please select correct operation")
# Out:
# Welcome to small level calculator
# Enter number 1: 456
# Enter number 2: 34
# 1. addition /n 2. subtraction /n 3. multiple /n 4. division
# Enter your choice: addition
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 16
#      14 n2 = int(input("Enter number 2:"))
#      15 print("1. addition /n 2. subtraction /n 3. multiple /n 4. division")
# ---> 16 choice = int(input("Enter your choice:"))
#      17 if choice == 1:
#      18     print("addition of two numbers s:", addition(n1,n2))
#
# ValueError: invalid literal for int() with base 10: 'addition'

# %%
# default arguments
def add(a,b,c = 0,d =0):
    return a + b + c + d
print(add(1,2))
print(add(1,2,3))
print(add(1,2,4))
# Out:
# 3
# 6
# 7

# %%
# default arguments
def mul(a,b,c = 0,d =0):
    return a * b * c * d
print(mul(1,2))
print(mul(1,2,3))
print(mul(1,2,4))
# Out:
# 0
# 0
# 0

# %%
# variable lenth of positional arguments
def add(a,*args):
    print(a)
    print(args)
    s = 0
    for num in args:
        s +=num
    return  s
    print(add(1,2,3,4,5))

# %% [markdown]
# #### lits operations
# - 1. concatination
# - 2. repeate

# %%
#list concatination
l1=[1,2,3]
l2=[3,2,1]
l3=l1 +l2
print(l3)
# Out:
# [1, 2, 3, 3, 2, 1]

# %%
# list repeate
l1=[ 1 , 2 , 3 ]
print( l1 * 2 )
print( l1 * 3 )
# Out:
# [1, 2, 3, 1, 2, 3]
# [1, 2, 3, 1, 2, 3, 1, 2, 3]

# %%
#add 100 elements to the end of the list
lst=[1,2,3]
#res= [1,2,3]
print(lst+[100])
# Out:
# [1, 2, 3, 100]

# %%
#empty list representation
l1=[]
l2=list()
print(type(l2))
print(len(l1),len(l2))
# Out:
# <class 'list'>
# 0 0

# %%
# default arguments
def add(a,b,c = 0,d =0):
    return a + b + c + d
print(add(1,2))
print(add(1,2,3))
print(add(1,2,4))
# Out:
# 3
# 6
# 7

# %%
### list
- ''' Adding elements to the list '''
- append (value) - it add the single value at the end of the list
-

# %%
lst =[1,2,3,4]
lst.append([10, 20, 30,])
print(lst)
# Out:
# [1, 2, 3, 4, [10, 20, 30]]

# %%
lst =[1,2,3,4]
lst.extend([10, 20, 30,])
print(lst)
# Out:
# [1, 2, 3, 4, 10, 20, 30]

# %%
st =[1,2,3,4]
lst.insert(2,100)
lst.insert(2,100)
print(lst)
# Out:
# [1, 2, 100, 100, 3, 4, 10, 20, 30]

# %%
st =[1,2,3,4]
lst.insert(2,100)
lst.insert(2,100)
print(lst)
lst. insert(100,1000)
print(lst)
# Out:
# [1, 2, 100, 100, 100, 100, 3, 4, 10, 20, 30]
# [1, 2, 100, 100, 100, 100, 3, 4, 10, 20, 30, 1000]

# %%
# Removing element function
lst = [1,2,3,4]
print(lst.pop)
print(lst.pop(3))
# Out:
# <built-in method pop of list object at 0x000001C83BDAD5C0>
# 4

# %%
lst =[1,2,3,3,4,3,4,5]
lst.remove(20)
print(lst)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 2
#       1 lst =[1,2,3,3,4,3,4,5]
# ----> 2 lst.remove(20)
#       3 print(lst)
#
# ValueError: list.remove(x): x not in list

# %%
lst =[1,2,3,3,4,3,4,5]
del lst [2:4]
print(lst)
# Out:
# [1, 2, 4, 3, 4, 5]

# %%
lst =[1,2,3,3,4,3,4,5]
print(lst,index(3))
print(lst,index(10))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 2
#       1 lst =[1,2,3,3,4,3,4,5]
# ----> 2 print(lst,index(3))
#       3 print(lst,index(10))
#
# NameError: name 'index' is not defined

# %%
# cinvert list of numbers into even list and odd list
l = list (map(int, input().split()))
even_num=[]
odd_num=[]
for num in lst:
    # check if num is even or odd
    if num % 2:
        odd_num.append(num)
    else:
        even_num.append(num)
print(even_nums)
print(odd_nums)

l2 = list (map (int,input().split()))
l1=[2,3,4,5,6]
l2=[2,6,8,9,5]
# Out:
#  odd and even
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 2
#       1 # cinvert list of numbers into even list and odd list
# ----> 2 l = list (map(int, input().split()))
#       3 even_num=[]
#       4 odd_num=[]
#
# ValueError: invalid literal for int() with base 10: 'odd'

# %%
# cinvert list of numbers into even list and odd list
l = list (map(int, input ().split()))
even_nums=[]
odd_nums=[]
for num in lst:
    # check if num is even or odd
    if num % 2:
        odd_num.append(nums)
    else:
        even_num.append(nums)
print(even_nums)
print(odd_nums)
# Out:
#  1 2 3 4 5 6 7
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[44], line 8
#       5 for num in lst:
#       6     # check if num is even or odd
#       7     if num % 2:
# ----> 8         odd_num.append(nums)
#       9     else:
#      10         even_num.append(nums)
#
# NameError: name 'nums' is not defined

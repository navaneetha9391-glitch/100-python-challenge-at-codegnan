# %%
s="CODEGNAN"

# %%
print(s)
# Out:
# CODEGNAN

# %% [markdown]
# # string operation
# ## string operation
# ### string operation
# #### string operation
# - string concatenation - (+)
#  - string repeat - (*)

# %%
# concatenation
s1="code"
s2="Gnan"
s3=s1+" "+s2
print (s3)
# Out:
# code Gnan

# %%
# string repeate
s= " CodeGnan "
print(s * 3)
# Out:
#  CodeGnan  CodeGnan  CodeGnan

# %%
s="navaneetha"
print(s[0])
print("s" + s[1:])
print(s) # navaneetha or navaneetha
# Out:
# n
# savaneetha
# navaneetha

# %%
s="navaneetha"
print(s[0])
y= "s" + s[1:]
print(y,s)
print("code" + "  " + "9")
# Out:
# n
# savaneetha navaneetha
# code  9

# %% [markdown]
# # string functions
#  - case converstion functions - lower(),upper(),title(),swapcase(),captilize()

# %%
s= "I am python BatcH studenT"
print(len(s))
print(s.lower())
print(s.upper())
print(s.title())  # in all words frist letter is capital
print(s.swapcase()) # if a word is captital then convert to small letter
print(s.capitalize()) # in sentance first word is captital another all are small
# Out:
# 25
# i am python batch student
# I AM PYTHON BATCH STUDENT
# I Am Python Batch Student
# i AM PYTHON bATCh STUDENt
# I am python batch student

# %%
# sub string index finding
#find()
s = "I am python BatcH studenT"
print(s.find("t"))
print(s.find("t",10)) # it will check the 10th position 
print(s.find("Z"))
print(s.index('t'))
print(s.find('Z'))
# Out:
# 7
# 14
# -1
# 7
# -1

# %%
#strip()- it removes the white space
s=  "    codegnan   "
print(s)
print(s.strip())
print(s.lstrip())
print(s.rstrip())
# Out:
#     codegnan
# codegnan
# codegnan
#     codegnan

# %%
#splist(sep) - it returns the list of substring and it 
s = "@@@@@@codegnan@@@@@@"
print(s)
print(s.strip('@'))
print(s.lstrip())
print(s.rstrip('@'))
# Out:
# @@@@@@codegnan@@@@@@
# codegnan
# @@@@@@codegnan@@@@@@
# @@@@@@codegnan

# %%
s= "I am python BatcH studenT"
print(s.split())
# Out:
# ['I', 'am', 'python', 'BatcH', 'studenT']

# %%
# case checking functions
s1 ="CODE"
s2 ="gnan"
s3 ="123"
s4 ="abc123"
s5 ="Codegnan"
print(s1.isupper())
print(s2.isupper())
print(s1.islower())
print(s2.islower())
print(s3.isdigit())
print(s4.isdigit())
print(s4.isalnum())
print(s4.isalpha())
print(s5.isalpha())
# Out:
# True
# False
# False
# True
# True
# False
# True
# False
# True

# %%
'navi' in 'navaneetha'
# Out:
# False

# %%
#username validation
      - minimum length - 8
      - atleast one uppercase and one lowercase letter
      - special charater ("_","@")
      - it contain digits
#password validation
# Out:
#   Cell In[14], line 2
#     - minimum length - 8
#     ^
# IndentationError: unexpected indent

# %%
# username and password validator using case check functions
#username
username=input("Enter username: ")
if len(username) >=8 and username[0].isalpha() : 
    for char in username:
        if char.isupper():
            has_upper=True
        elif char.islower():
            has_lower=True
        elif char.isdigit():
            has_digit=True
        elif char in ["_","@"]:
            has_special=True
    if has_upper and has_lower and has_digit and has_special:
        print("Username is valid!")
    else:
        print("Username is not valid!")
else:
    print("Username is not valid!")

#password 
password=input("Enter password: ")
if len(password) >=8 and password[0].isalpha() : 
    for char in password:
        if char.isupper():
            has_upper=True
        elif char.islower():
            has_lower=True
            elif char.isdigit():
            has_digit=True
        elif char in ["_","@"]:
            has_special=True
    if has_upper and has_lower and has_digit and has_special:
        print("Password is valid!")
    else:
        print("Password is not valid!")
else:
    print("Password is not valid!")
